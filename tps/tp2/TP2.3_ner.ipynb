# %% [markdown]
# # Reconnaissance d'entités nommées avec SpaCy

# %% [markdown]
# La documentation est accessible ici: https://spacy.io/api

# %% [markdown]
# ## Imports

# %%
from collections import defaultdict
import spacy
from spacy.lang.fr.examples import sentences
# !pip install  fr_core_news_md
# Out:
# Requirement already satisfied: fr_core_news_md in c:\users\fatig\tac\tac_venv\lib\site-packages (3.5.0)
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from fr_core_news_md) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (3.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (1.26.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (1.10.13)
# Requirement already satisfied: jinja2 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->fr_core_news_md) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\fatig\tac\tac_venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->fr_core_news_md) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\fatig\tac\tac_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fatig\tac\tac_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fatig\tac\tac_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fatig\tac\tac_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (2025.10.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\fatig\tac\tac_venv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->fr_core_news_md) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\fatig\tac\tac_venv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->fr_core_news_md) (0.1.5)
# Requirement already satisfied: colorama in c:\users\fatig\tac\tac_venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\fatig\tac\tac_venv\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (8.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (1.3.1)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\fatig\tac\tac_venv\lib\site-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->fr_core_news_md) (0.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fatig\tac\tac_venv\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->fr_core_news_md) (3.0.3)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
nlp = spacy.load('fr_core_news_md')

# %% [markdown]
# ## Exemple sur un corpus de test fourni par SpaCy

# %%
# Imprimer le corpus de Spacy
sentences
# Out:
# ['Apple cherche à acheter une start-up anglaise pour 1 milliard de dollars',
#  "Les voitures autonomes déplacent la responsabilité de l'assurance vers les constructeurs",
#  "San Francisco envisage d'interdire les robots coursiers sur les trottoirs",
#  'Londres est une grande ville du Royaume-Uni',
#  'L’Italie choisit ArcelorMittal pour reprendre la plus grande aciérie d’Europe',
#  "Apple lance HomePod parce qu'il se sent menacé par l'Echo d'Amazon",
#  "La France ne devrait pas manquer d'électricité cet été, même en cas de canicule",
#  'Nouvelles attaques de Trump contre le maire de Londres',
#  'Où es-tu ?',
#  'Qui est le président de la France ?',
#  'Où est la capitale des États-Unis ?',
#  'Quand est né Barack Obama ?']

# %%
# Isoler la première phrase
sent = sentences[0]
sent
# Out:
# 'Apple cherche à acheter une start-up anglaise pour 1 milliard de dollars'

# %%
# Traiter la phrase avec Spacy
doc = nlp(sent)

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc.text
# Out:
# 'Apple cherche à acheter une start-up anglaise pour 1 milliard de dollars'

# %%
doc.to_json()
# Out:
# {'text': 'Apple cherche à acheter une start-up anglaise pour 1 milliard de dollars',
#  'ents': [{'start': 0, 'end': 5, 'label': 'ORG'}],
#  'sents': [{'start': 0, 'end': 72}],
#  'tokens': [{'id': 0,
#    'start': 0,
#    'end': 5,
#    'tag': 'PROPN',
#    'pos': 'PROPN',
#    'morph': '',
#    'lemma': 'Apple',
#    'dep': 'nsubj',
#    'head': 1},
#   {'id': 1,
#    'start': 6,
#    'end': 13,
#    'tag': 'VERB',
#    'pos': 'VERB',
#    'morph': 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'lemma': 'cherche',
#    'dep': 'ROOT',
#    'head': 1},
#   {'id': 2,
#    'start': 14,
#    'end': 15,
#    'tag': 'ADP',
#    'pos': 'ADP',
#    'morph': '',
#    'lemma': 'à',
#    'dep': 'mark',
#    'head': 3},
#   {'id': 3,
#    'start': 16,
#    'end': 23,
#    'tag': 'VERB',
#    'pos': 'VERB',
#    'morph': 'VerbForm=Inf',
#    'lemma': 'acheter',
#    'dep': 'xcomp',
#    'head': 1},
#   {'id': 4,
#    'start': 24,
#    'end': 27,
#    'tag': 'DET',
#    'pos': 'DET',
#    'morph': 'Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#    'lemma': 'un',
#    'dep': 'det',
#    'head': 5},
#   {'id': 5,
#    'start': 28,
#    'end': 33,
#    'tag': 'NOUN',
#    'pos': 'NOUN',
#    'morph': 'Gender=Fem|Number=Plur',
#    'lemma': 'start',
#    'dep': 'obl:arg',
#    'head': 3},
#   {'id': 6,
#    'start': 33,
#    'end': 34,
#    'tag': 'PROPN',
#    'pos': 'PROPN',
#    'morph': '',
#    'lemma': '-',
#    'dep': 'obl:mod',
#    'head': 3},
#   {'id': 7,
#    'start': 34,
#    'end': 36,
#    'tag': 'X',
#    'pos': 'X',
#    'morph': '',
#    'lemma': 'up',
#    'dep': 'obj',
#    'head': 3},
#   {'id': 8,
#    'start': 37,
#    'end': 45,
#    'tag': 'ADJ',
#    'pos': 'ADJ',
#    'morph': 'Gender=Fem|Number=Sing',
#    'lemma': 'anglais',
#    'dep': 'amod',
#    'head': 7},
#   {'id': 9,
#    'start': 46,
#    'end': 50,
#    'tag': 'ADP',
#    'pos': 'ADP',
#    'morph': '',
#    'lemma': 'pour',
#    'dep': 'case',
#    'head': 11},
#   {'id': 10,
#    'start': 51,
#    'end': 52,
#    'tag': 'NUM',
#    'pos': 'NUM',
#    'morph': 'NumType=Card',
#    'lemma': '1',
#    'dep': 'nummod',
#    'head': 11},
#   {'id': 11,
#    'start': 53,
#    'end': 61,
#    'tag': 'NOUN',
#    'pos': 'NOUN',
#    'morph': 'Gender=Masc|NumType=Card|Number=Sing',
#    'lemma': 'milliard',
#    'dep': 'obl:mod',
#    'head': 3},
#   {'id': 12,
#    'start': 62,
#    'end': 64,
#    'tag': 'ADP',
#    'pos': 'ADP',
#    'morph': '',
#    'lemma': 'de',
#    'dep': 'case',
#    'head': 13},
#   {'id': 13,
#    'start': 65,
#    'end': 72,
#    'tag': 'NOUN',
#    'pos': 'NOUN',
#    'morph': 'Gender=Masc|Number=Plur',
#    'lemma': 'dollar',
#    'dep': 'nmod',
#    'head': 11}]}

# %%
# Appliquer le test sur toutes les phrases
for sent in sentences:
    doc = nlp(sent)
    entities = []
    for ent in doc.ents:
        entities.append(f"{ent.text} ({ent.label_})")
    if entities:
        print(f"'{doc.text}' contient les entités suivantes : {', '.join(entities)}")
    else:
        print(f"'{doc.text}' ne contient aucune entité")
# Out:
# 'Apple cherche à acheter une start-up anglaise pour 1 milliard de dollars' contient les entités suivantes : Apple (ORG)
# 'Les voitures autonomes déplacent la responsabilité de l'assurance vers les constructeurs' ne contient aucune entité
# 'San Francisco envisage d'interdire les robots coursiers sur les trottoirs' contient les entités suivantes : San Francisco (LOC)
# 'Londres est une grande ville du Royaume-Uni' contient les entités suivantes : Londres (LOC), Royaume-Uni (LOC)
# 'L’Italie choisit ArcelorMittal pour reprendre la plus grande aciérie d’Europe' contient les entités suivantes : L’Italie (LOC), ArcelorMittal (ORG), Europe (LOC)
# 'Apple lance HomePod parce qu'il se sent menacé par l'Echo d'Amazon' contient les entités suivantes : Apple (ORG), HomePod (MISC), Echo (MISC), Amazon (ORG)
# 'La France ne devrait pas manquer d'électricité cet été, même en cas de canicule' contient les entités suivantes : La France (LOC)
# 'Nouvelles attaques de Trump contre le maire de Londres' contient les entités suivantes : Nouvelles attaques (MISC), Trump (PER), Londres (LOC)
# 'Où es-tu ?' ne contient aucune entité
# 'Qui est le président de la France ?' contient les entités suivantes : la France (LOC)
# 'Où est la capitale des États-Unis ?' contient les entités suivantes : États-Unis (LOC)
# 'Quand est né Barack Obama ?' contient les entités suivantes : Barack Obama (PER)

# %% [markdown]
# ## Appliquer la reconnaissance d'entités nommées sur notre corpus

# %%
# Charger le texte juste pour l'année 1961
year = 1961
n = 1000000
data_path = '../../data'
txt_path = '../../data/txt'
text = open("../../data/tmp/1961_clean.txt", encoding='utf-8').read()[:n]

# %%
# %%time
# Traiter le texte

doc = nlp(text)
# Out:
# CPU times: total: 28.6 s
# Wall time: 32.3 s

# %%
# Compter les entités
people = defaultdict(int)
for ent in doc.ents:
    if ent.label_ == "PER" and len(ent.text) > 3:
        people[ent.text] += 1

# %%
# Trier et imprimer

sorted_people = sorted(people.items(), key=lambda kv: kv[1], reverse=True)

for person, freq in sorted_people[:50]:
    print(f"{person} apparait {freq} fois dans le corpus")
# Out:
# COVERCAL SUPER apparait 2 fois dans le corpus
# LÉGÈRES apparait 2 fois dans le corpus
# BARDOT BOUTVIL apparait 1 fois dans le corpus
# QUIER STERNBERG apparait 1 fois dans le corpus
# FAUDRA PAYER apparait 1 fois dans le corpus
# BORDURES DESREVÔTÈNIENTS apparait 1 fois dans le corpus
# CEILES MARÉCHAL GÉNÉRAL apparait 1 fois dans le corpus
# OEDELEM CHUTE VÉLOMOTEUR apparait 1 fois dans le corpus
# LOURDS DIESELS apparait 1 fois dans le corpus
# CURRIC apparait 1 fois dans le corpus
# SOUMA MEX apparait 1 fois dans le corpus
# LUVANDIÈRO III apparait 1 fois dans le corpus
# DÉPLORABLE INCONTESTABLEMENT apparait 1 fois dans le corpus
# FAITS BREF apparait 1 fois dans le corpus
# VILLA NEUVE FINI apparait 1 fois dans le corpus
# LIBRE RAPLDT apparait 1 fois dans le corpus
# LESSIVEUSE TELÊCA apparait 1 fois dans le corpus
# LLSMONT apparait 1 fois dans le corpus
# VENAIT CREVER apparait 1 fois dans le corpus
# ZINA HARAIGNE INCULPÉE apparait 1 fois dans le corpus
# UOS INCUUOO JJODS apparait 1 fois dans le corpus
# RUA NEUVE apparait 1 fois dans le corpus
# ARSÈNE apparait 1 fois dans le corpus
# LOUIS LANGHEN apparait 1 fois dans le corpus
# RIUS NECKEBROEEK apparait 1 fois dans le corpus
# LOUIS DEN apparait 1 fois dans le corpus
# LOUIS MARCQ apparait 1 fois dans le corpus
# BLSCHOFFSHEIM apparait 1 fois dans le corpus
# IDESSINATEURS FOUR apparait 1 fois dans le corpus
# LOUIS BOXUS apparait 1 fois dans le corpus
# DOIVENT ARRIVER HEURES apparait 1 fois dans le corpus
# ROUF PER apparait 1 fois dans le corpus
# LOUIS PERS apparait 1 fois dans le corpus
# CHOPIN THLRD apparait 1 fois dans le corpus
# GENRES FOX apparait 1 fois dans le corpus
# MARINS FAMILIERS apparait 1 fois dans le corpus
# CHAUSSÉE FOREST apparait 1 fois dans le corpus
# FIAI apparait 1 fois dans le corpus
# RÉPONDIT BUVANT apparait 1 fois dans le corpus
# CROIS RYEUXÏ apparait 1 fois dans le corpus
# LOUIS XIII apparait 1 fois dans le corpus
# MARI DEH DAME apparait 1 fois dans le corpus
# REP HAH apparait 1 fois dans le corpus
# VÉTÉRINAIRES BRNX apparait 1 fois dans le corpus
# IMMEUB COMM MIROITERIE apparait 1 fois dans le corpus
# LOUER DEPOT VOLXEM apparait 1 fois dans le corpus
# VEND LBILRUN apparait 1 fois dans le corpus
# TIRLEMONT apparait 1 fois dans le corpus
# CERTAINE apparait 1 fois dans le corpus
# LOUIS DELLUC apparait 1 fois dans le corpus

# %% [markdown]
# Exercice: essayez de lister les lieux (LOC) et les organisations (ORG) les plus mentionnées dans le corpus
